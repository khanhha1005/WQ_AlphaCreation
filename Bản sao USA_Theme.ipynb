# %% [markdown]
# ### Import library

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_RDgxw9L7CL7oeAdAZhgMX2BKG3c9

# %% [markdown]
# ### Create list of alpha expressions
# #### Step 1. Download datsets

# %%
############################### Equity ,Region, Delay , Top ################################
datasets_df = hf.get_datasets(s,'EQUITY','USA','1') # by default we load all datasets USA TOP3000 delay 1
# get me the name of row equal Sentiment Data for Equity
# sentiment_data_name = datasets_df[datasets_df['name'] == 'Sentiment Data for Equity']
#sentiment_data_name

# %%
#get me all the rows that contain the word other, news, socialmedia in the category column and seperate each in a different dataframe
other_df = datasets_df[datasets_df['category'].str.contains('other', case=False)].reset_index(drop=True)
news_df = datasets_df[datasets_df['category'].str.contains('news', case=False)].reset_index(drop=True)
socialmedia_df = datasets_df[datasets_df['category'].str.contains('socialmedia', case=False)].reset_index(drop=True)

# %%
selected_datasets_df =news_df[(news_df['alphaCount']> 10)& (news_df['userCount']>10) ]

# %% [markdown]
# For demonstration we are picking the dataset with the highest value score, this is not mandatory but definitely a recommended practice

# %% [markdown]
# #### Step 2. Select the needed datafields

# %%
dataset_id = selected_datasets_df.id.values.tolist() # create a list of selected datasets ids, our list has only one element

# %%
all_data_field = []
for i in dataset_id:
    datafields_df = hf.get_datafields(s, dataset_id=i) # download all fields of dataset news
    all_data_field.append(datafields_df.id.values.tolist())

# %%
# merge all element in all_data_field into one list 
all_data_field = [item for sublist in all_data_field for item in sublist]

# %%
all_data_field
# Out:
# ['news_all_vwap',
#  'news_atr14',
#  'news_atr_ratio',
#  'news_cap',
#  'news_close_vol',
#  'news_curr_vol',
#  'news_dividend_yield',
#  'news_eod_close',
#  'news_eod_high',
#  'news_eod_low',
#  'news_eod_vwap',
#  'news_eps_actual',
#  'news_high_exc_stddev',
#  'news_indx_perf',
#  'news_low_exc_stddev',
#  'news_ls',
#  'news_main_vwap',
#  'news_max_dn_amt',
#  'news_max_dn_ret',
#  'news_max_up_amt',
#  'news_max_up_ret',
#  'news_mins_10_chg',
#  'news_mins_10_pct_dn',
#  'news_mins_10_pct_up',
#  'news_mins_1_chg',
#  'news_mins_1_pct_dn',
#  'news_mins_1_pct_up',
#  'news_mins_20_chg',
#  'news_mins_20_pct_dn',
#  'news_mins_20_pct_up',
#  'news_mins_2_chg',
#  'news_mins_2_pct_dn',
#  'news_mins_2_pct_up',
#  'news_mins_3_chg',
#  'news_mins_3_pct_dn',
#  'news_mins_3_pct_up',
#  'news_mins_4_chg',
#  'news_mins_4_pct_dn',
#  'news_mins_4_pct_up',
#  'news_mins_5_chg',
#  'news_mins_5_pct_dn',
#  'news_mins_5_pct_up',
#  'news_mins_7_5_chg',
#  'news_mins_7_5_pct_dn',
#  'news_mins_7_5_pct_up',
#  'news_mov_vol',
#  'news_open',
#  'news_open_gap',
#  'news_open_vol',
#  'news_pct_10min',
#  'news_pct_120min',
#  'news_pct_1min',
#  'news_pct_30min',
#  'news_pct_30sec',
#  'news_pct_5_min',
#  'news_pct_60min',
#  'news_pct_90min',
#  'news_pe_ratio',
#  'news_post_vwap',
#  'news_pre_vwap',
#  'news_prev_close',
#  'news_prev_day_ret',
#  'news_prev_vol',
#  'news_range_stddev',
#  'news_ratio_vol',
#  'news_session_range',
#  'news_session_range_pct',
#  'news_short_interest',
#  'news_spy_close',
#  'news_spy_last',
#  'news_ton_high',
#  'news_ton_last',
#  'news_ton_low',
#  'news_tot_ticks',
#  'news_vol_stddev',
#  'nws12_afterhsz_01l',
#  'nws12_afterhsz_01p',
#  'nws12_afterhsz_01s',
#  'nws12_afterhsz_02l',
#  'nws12_afterhsz_02p',
#  'nws12_afterhsz_02s',
#  'nws12_afterhsz_10_min',
#  'nws12_afterhsz_120_min',
#  'nws12_afterhsz_1_minute',
#  'nws12_afterhsz_1l',
#  'nws12_afterhsz_1p',
#  'nws12_afterhsz_1s',
#  'nws12_afterhsz_2l',
#  'nws12_afterhsz_2p',
#  'nws12_afterhsz_2s',
#  'nws12_afterhsz_30_min',
#  'nws12_afterhsz_3l',
#  'nws12_afterhsz_3p',
#  'nws12_afterhsz_3s',
#  'nws12_afterhsz_41rta',
#  'nws12_afterhsz_4l',
#  'nws12_afterhsz_4p',
#  'nws12_afterhsz_4s',
#  'nws12_afterhsz_57l',
#  'nws12_afterhsz_57p',
#  'nws12_afterhsz_57s',
#  'nws12_afterhsz_5_min',
#  'nws12_afterhsz_5l',
#  'nws12_afterhsz_5p',
#  'nws12_afterhsz_5s',
#  'nws12_afterhsz_60_min',
#  'nws12_afterhsz_90_min',
#  'nws12_afterhsz_allticks',
#  'nws12_afterhsz_atrratio',
#  'nws12_afterhsz_close_vol',
#  'nws12_afterhsz_curr_vol',
#  'nws12_afterhsz_dayopen',
#  'nws12_afterhsz_div_y',
#  'nws12_afterhsz_eodclose',
#  'nws12_afterhsz_eodhigh',
#  'nws12_afterhsz_eodlow',
#  'nws12_afterhsz_eodvwap',
#  'nws12_afterhsz_epsactual',
#  'nws12_afterhsz_highexcstddev',
#  'nws12_afterhsz_lowexcstddev',
#  'nws12_afterhsz_mainvwap',
#  'nws12_afterhsz_maxdnamt',
#  'nws12_afterhsz_maxdown',
#  'nws12_afterhsz_maxup',
#  'nws12_afterhsz_maxupamt',
#  'nws12_afterhsz_mktcap',
#  'nws12_afterhsz_mov_vol',
#  'nws12_afterhsz_newrecord',
#  'nws12_afterhsz_newssess',
#  'nws12_afterhsz_open_vol',
#  'nws12_afterhsz_opengap',
#  'nws12_afterhsz_peratio',
#  'nws12_afterhsz_postvwap',
#  'nws12_afterhsz_prev_vol',
#  'nws12_afterhsz_prevclose',
#  'nws12_afterhsz_prevday',
#  'nws12_afterhsz_prevwap',
#  'nws12_afterhsz_provider',
#  'nws12_afterhsz_range',
#  'nws12_afterhsz_rangeamt',
#  'nws12_afterhsz_rangestddev',
#  'nws12_afterhsz_reportsess',
#  'nws12_afterhsz_result1',
#  'nws12_afterhsz_result2',
#  'nws12_afterhsz_result_vs_index',
#  'nws12_afterhsz_short_interest',
#  'nws12_afterhsz_sl',
#  'nws12_afterhsz_spyclose',
#  'nws12_afterhsz_spylast',
#  'nws12_afterhsz_tonhigh',
#  'nws12_afterhsz_tonlast',
#  'nws12_afterhsz_tonlow',
#  'nws12_afterhsz_vol_ratio',
#  'nws12_afterhsz_volstddev',
#  'nws12_allz_newrecord',
#  'nws12_allz_newssess',
#  'nws12_allz_provider',
#  'nws12_allz_reportsess',
#  'nws12_allz_result1',
#  'nws12_allz_result2',
#  'nws12_mainz_01l',
#  'nws12_mainz_01p',
#  'nws12_mainz_01s',
#  'nws12_mainz_02l',
#  'nws12_mainz_02p',
#  'nws12_mainz_02s',
#  'nws12_mainz_10_min',
#  'nws12_mainz_120_min',
#  'nws12_mainz_1_minute',
#  'nws12_mainz_1l',
#  'nws12_mainz_1p',
#  'nws12_mainz_1s',
#  'nws12_mainz_2l',
#  'nws12_mainz_2p',
#  'nws12_mainz_2s',
#  'nws12_mainz_30_min',
#  'nws12_mainz_30_seconds',
#  'nws12_mainz_3l',
#  'nws12_mainz_3p',
#  'nws12_mainz_3s',
#  'nws12_mainz_41rta',
#  'nws12_mainz_4l',
#  'nws12_mainz_4p',
#  'nws12_mainz_4s',
#  'nws12_mainz_57l',
#  'nws12_mainz_57p',
#  'nws12_mainz_57s',
#  'nws12_mainz_5_min',
#  'nws12_mainz_5l',
#  'nws12_mainz_5p',
#  'nws12_mainz_5s',
#  'nws12_mainz_60_min',
#  'nws12_mainz_90_min',
#  'nws12_mainz_allticks',
#  'nws12_mainz_allvwap',
#  'nws12_mainz_atrratio',
#  'nws12_mainz_close_vol',
#  'nws12_mainz_curr_vol',
#  'nws12_mainz_dayopen',
#  'nws12_mainz_div_y',
#  'nws12_mainz_eodclose',
#  'nws12_mainz_eodhigh',
#  'nws12_mainz_eodlow',
#  'nws12_mainz_eodvwap',
#  'nws12_mainz_epsactual',
#  'nws12_mainz_highexcstddev',
#  'nws12_mainz_lowexcstddev',
#  'nws12_mainz_mainvwap',
#  'nws12_mainz_maxdnamt',
#  'nws12_mainz_maxdown',
#  'nws12_mainz_maxup',
#  'nws12_mainz_maxupamt',
#  'nws12_mainz_mktcap',
#  'nws12_mainz_mov_vol',
#  'nws12_mainz_newrecord',
#  'nws12_mainz_newssess',
#  'nws12_mainz_open_vol',
#  'nws12_mainz_opengap',
#  'nws12_mainz_peratio',
#  'nws12_mainz_postvwap',
#  'nws12_mainz_prev_vol',
#  'nws12_mainz_prevclose',
#  'nws12_mainz_prevday',
#  'nws12_mainz_prevwap',
#  'nws12_mainz_provider',
#  'nws12_mainz_range',
#  'nws12_mainz_rangeamt',
#  'nws12_mainz_rangestddev',
#  'nws12_mainz_reportsess',
#  'nws12_mainz_result1',
#  'nws12_mainz_result2',
#  'nws12_mainz_result_vs_index',
#  'nws12_mainz_short_interest',
#  'nws12_mainz_sl',
#  'nws12_mainz_spyclose',
#  'nws12_mainz_spylast',
#  'nws12_mainz_tonhigh',
#  'nws12_mainz_tonlast',
#  'nws12_mainz_tonlow',
#  'nws12_mainz_vol_ratio',
#  'nws12_mainz_volstddev',
#  'nws12_prez_01l',
#  'nws12_prez_01p',
#  'nws12_prez_01s',
#  'nws12_prez_02l',
#  'nws12_prez_02p',
#  'nws12_prez_02s',
#  'nws12_prez_10_min',
#  'nws12_prez_120_min',
#  'nws12_prez_1_minute',
#  'nws12_prez_1l',
#  'nws12_prez_1p',
#  'nws12_prez_1s',
#  'nws12_prez_2l',
#  'nws12_prez_2p',
#  'nws12_prez_2s',
#  'nws12_prez_30_min',
#  'nws12_prez_30_seconds',
#  'nws12_prez_3l',
#  'nws12_prez_3p',
#  'nws12_prez_3s',
#  'nws12_prez_41rta',
#  'nws12_prez_4l',
#  'nws12_prez_4p',
#  'nws12_prez_4s',
#  'nws12_prez_57l',
#  'nws12_prez_57p',
#  'nws12_prez_57s',
#  'nws12_prez_5_min',
#  'nws12_prez_5l',
#  'nws12_prez_5p',
#  'nws12_prez_5s',
#  'nws12_prez_60_min',
#  'nws12_prez_90_min',
#  'nws12_prez_allticks',
#  'nws12_prez_allvwap',
#  'nws12_prez_atrratio',
#  'nws12_prez_close_vol',
#  'nws12_prez_curr_vol',
#  'nws12_prez_dayopen',
#  'nws12_prez_div_y',
#  'nws12_prez_eodclose',
#  'nws12_prez_eodhigh',
#  'nws12_prez_eodlow',
#  'nws12_prez_eodvwap',
#  'nws12_prez_epsactual',
#  'nws12_prez_highexcstddev',
#  'nws12_prez_lowexcstddev',
#  'nws12_prez_mainvwap',
#  'nws12_prez_maxdnamt',
#  'nws12_prez_maxdown',
#  'nws12_prez_maxup',
#  'nws12_prez_maxupamt',
#  'nws12_prez_mktcap',
#  'nws12_prez_mov_vol',
#  'nws12_prez_newrecord',
#  'nws12_prez_newssess',
#  'nws12_prez_open_vol',
#  'nws12_prez_opengap',
#  'nws12_prez_peratio',
#  'nws12_prez_postvwap',
#  'nws12_prez_prev_vol',
#  'nws12_prez_prevclose',
#  'nws12_prez_prevday',
#  'nws12_prez_prevwap',
#  'nws12_prez_provider',
#  'nws12_prez_range',
#  'nws12_prez_rangeamt',
#  'nws12_prez_rangestddev',
#  'nws12_prez_reportsess',
#  'nws12_prez_result1',
#  'nws12_prez_result2',
#  'nws12_prez_result_vs_index',
#  'nws12_prez_short_interest',
#  'nws12_prez_sl',
#  'nws12_prez_spyclose',
#  'nws12_prez_spylast',
#  'nws12_prez_tonhigh',
#  'nws12_prez_tonlast',
#  'nws12_prez_tonlow',
#  'nws12_prez_vol_ratio',
#  'nws12_prez_volstddev',
#  'nws17_d1_acb',
#  'nws17_d1_bam',
#  'nws17_d1_bee',
#  'nws17_d1_ber',
#  'nws17_d1_country_code',
#  'nws17_d1_event_end_time_utc',
#  'nws17_d1_event_relevance',
#  'nws17_d1_event_sentiment_score',
#  'nws17_d1_event_similarity_days',
#  'nws17_d1_event_start_time_utc',
#  'nws17_d1_event_text',
#  'nws17_d1_headline',
#  'nws17_d1_nip',
#  'nws17_d1_qcm',
#  'nws17_d1_qep',
#  'nws17_d1_qmb',
#  'nws17_d1_relevance',
#  'nws17_d1_reporting_end_time_utc',
#  'nws17_d1_reporting_start_time_utc',
#  'nws17_d1_rp_story_event_count',
#  'nws17_d1_rp_story_event_index',
#  'nws17_d1_ssc',
#  'nws17_d1_timestamp_utc_time',
#  'nws18_acb',
#  'nws18_bam',
#  'nws18_bee',
#  'nws18_ber',
#  'nws18_event_relevance',
#  'nws18_event_similarity_days',
#  'nws18_ghc_lna',
#  'nws18_nip',
#  'nws18_qcm',
#  'nws18_qep',
#  'nws18_qmb',
#  'nws18_relevance',
#  'nws18_ssc',
#  'nws18_sse',
#  'rp_css_assets',
#  'rp_css_business',
#  'rp_css_credit',
#  'rp_css_credit_ratings',
#  'rp_css_dividends',
#  'rp_css_earnings',
#  'rp_css_equity',
#  'rp_css_insider',
#  'rp_css_inverstor',
#  'rp_css_labor',
#  'rp_css_legal',
#  'rp_css_marketing',
#  'rp_css_mna',
#  'rp_css_partner',
#  'rp_css_price',
#  'rp_css_product',
#  'rp_css_ptg',
#  'rp_css_ratings',
#  'rp_css_revenue',
#  'rp_css_society',
#  'rp_css_technical',
#  'rp_ess_assets',
#  'rp_ess_business',
#  'rp_ess_credit',
#  'rp_ess_credit_ratings',
#  'rp_ess_dividends',
#  'rp_ess_earnings',
#  'rp_ess_equity',
#  'rp_ess_insider',
#  'rp_ess_labor',
#  'rp_ess_legal',
#  'rp_ess_mna',
#  'rp_ess_partner',
#  'rp_ess_price',
#  'rp_ess_product',
#  'rp_ess_ptg',
#  'rp_ess_ratings',
#  'rp_ess_revenue',
#  'rp_ess_society',
#  'rp_ess_technical',
#  'rp_nip_assets',
#  'rp_nip_business',
#  'rp_nip_credit',
#  'rp_nip_credit_ratings',
#  'rp_nip_dividends',
#  'rp_nip_earnings',
#  'rp_nip_equity',
#  'rp_nip_insider',
#  'rp_nip_inverstor',
#  'rp_nip_labor',
#  'rp_nip_legal',
#  'rp_nip_marketing',
#  'rp_nip_mna',
#  'rp_nip_partner',
#  'rp_nip_price',
#  'rp_nip_product',
#  'rp_nip_ptg',
#  'rp_nip_ratings',
#  'rp_nip_revenue',
#  'rp_nip_society',
#  'rp_nip_technical',
#  'nws20_d1_acb',
#  'nws20_d1_bam',
#  'nws20_d1_bee',
#  'nws20_d1_ber',
#  'nws20_d1_country_code',
#  'nws20_d1_event_end_time_utc',
#  'nws20_d1_event_relevance',
#  'nws20_d1_event_sentiment_score',
#  'nws20_d1_event_similarity_days',
#  'nws20_d1_event_start_time_utc',
#  'nws20_d1_event_text',
#  'nws20_d1_ghc_lna',
#  'nws20_d1_headline',
#  'nws20_d1_nip',
#  'nws20_d1_qcm',
#  'nws20_d1_qep',
#  'nws20_d1_qmb',
#  'nws20_d1_relevance',
#  'nws20_d1_reporting_end_time_utc',
#  'nws20_d1_reporting_start_time_utc',
#  'nws20_d1_rp_story_event_count',
#  'nws20_d1_rp_story_event_index',
#  'nws20_d1_ssc',
#  'nws20_d1_timestamp_utc_time',
#  'nws21_abz1neg_eventid',
#  'nws21_abz1neg_eventtype',
#  'nws21_abz1neg_storyid',
#  'nws21_abz1neg_version',
#  'nws21_abz1negv_exptime',
#  'nws21_abz1negv_lastuptime',
#  'nws21_abz1negv_starttime',
#  'nws21_abz1pos_eventid',
#  'nws21_abz1pos_eventtype',
#  'nws21_abz1pos_storyid',
#  'nws21_abz1pos_version',
#  'nws21_abz1posaz_exptime',
#  'nws21_abz1posaz_lastuptime',
#  'nws21_abz1posaz_starttime',
#  'nws21_abz2_eventtype',
#  'nws21_abz2_neg_freq',
#  'nws21_abz2_neg_sc',
#  'nws21_abz2_pos_freq',
#  'nws21_abz2_pos_sc',
#  'nws21_abz2_tone_sc',
#  'nws21_abz2_version',
#  'nws21_abz31a1_eventtype',
#  'nws21_abz31a1_neg_freq',
#  'nws21_abz31a1_neg_sc',
#  'nws21_abz31a1_pos_freq',
#  'nws21_abz31a1_pos_sc',
#  'nws21_abz31a1_tone_sc',
#  'nws21_abz31a1_version',
#  'nws21_abz3_g09_eventtype',
#  'nws21_abz3_g09_neg_freq',
#  'nws21_abz3_g09_neg_sc',
#  'nws21_abz3_g09_pos_freq',
#  'nws21_abz3_g09_pos_sc',
#  'nws21_abz3_g09_tone_sc',
#  'nws21_abz3_g09_version',
#  'nws21_abz3_g09_vinlastevent',
#  'nws21_abz3a2_eventtype',
#  'nws21_abz3a2_neg_freq',
#  'nws21_abz3a2_neg_sc',
#  'nws21_abz3a2_pos_freq',
#  'nws21_abz3a2_pos_sc',
#  'nws21_abz3a2_tone_sc',
#  'nws21_abz3a2_version',
#  'nws21_abz3a2_vinlastevent',
#  'nws21_abz3az_eventtype',
#  'nws21_abz3az_neg_freq',
#  'nws21_abz3az_neg_sc',
#  'nws21_abz3az_pos_freq',
#  'nws21_abz3az_pos_sc',
#  'nws21_abz3az_tone_sc',
#  'nws21_abz3az_version',
#  'nws21_abz4s2_eventtype',
#  'nws21_abz4s2_neg_freq',
#  'nws21_abz4s2_neg_sc',
#  'nws21_abz4s2_pos_freq',
#  'nws21_abz4s2_pos_sc',
#  'nws21_abz4s2_tone_sc',
#  'nws21_abz4s2_version',
#  'nws21_neg_firstpartoffset',
#  'nws21_neg_parttype',
#  'nws21_neg_totalwords',
#  'nws21_participants',
#  'nws21_pos_firstpartoffset',
#  'nws21_pos_parttype',
#  'nws21_pos_totalwords',
#  'nws21_qa_count',
#  'nws21_qerf',
#  'se_event_count',
#  'se_neg_score',
#  'se_neg_words',
#  'se_pos_score',
#  'se_pos_words',
#  'se_score',
#  'mws22_headline',
#  'mws22_qes',
#  'mws22_wqrcvtime_time',
#  'nws3_scores_certaintynormscr',
#  'nws3_scores_certaintypartnormscr',
#  'nws3_scores_fearnormscr',
#  'nws3_scores_fearpartnormscr',
#  'nws3_scores_findownnormscr',
#  'nws3_scores_findownpartnormscr',
#  'nws3_scores_finhypenormscr',
#  'nws3_scores_finhypepartnormscr',
#  'nws3_scores_finupnormscr',
#  'nws3_scores_finuppartnormscr',
#  'nws3_scores_finvolatilenormscr',
#  'nws3_scores_finvolatilepartnormscr',
#  'nws3_scores_negnormscr',
#  'nws3_scores_negpartnormscr',
#  'nws3_scores_posnormscr',
#  'nws3_scores_pospartnormscr',
#  'nws3_scores_uncertaintynormscr',
#  'nws3_scores_uncertaintypartnormscr',
#  'nws3_wqreceivetime',
#  'nws31_amertimestamp_date',
#  'nws31_amertimestamp_time',
#  'nws31_apactimestamp_date',
#  'nws31_apactimestamp_time',
#  'nws31_audiences',
#  'nws31_d1_bodysize',
#  'nws31_d1_companycount',
#  'nws31_d1_feedtimestamp_date',
#  'nws31_d1_feedtimestamp_time',
#  'nws31_d1_firstcreated_date',
#  'nws31_d1_firstcreated_time',
#  'nws31_d1_firstmentionsentence',
#  'nws31_d1_noveltycounts',
#  'nws31_d1_relevance',
#  'nws31_d1_sentencecount',
#  'nws31_d1_sentimentClass',
#  'nws31_d1_sentimentnegative',
#  'nws31_d1_sentimentneutral',
#  'nws31_d1_sentimentpositive',
#  'nws31_d1_sentimentwordcount',
#  'nws31_d1_sourcetimestamp_date',
#  'nws31_d1_sourcetimestamp_time',
#  'nws31_d1_urgency',
#  'nws31_d1_volumecounts',
#  'nws31_d1_wordcount',
#  'nws31_emeatimestamp_date',
#  'nws31_emeatimestamp_time',
#  'nws31_linkedidpositions',
#  'nws31_linkedidvalues',
#  'nws31_subjects',
#  'nws31_windows',
#  'mws36_key_event_confidence',
#  'mws36_novelty',
#  'mws36_novelty_newest_span',
#  'mws36_novelty_oldest_span',
#  'mws36_relevance',
#  'mws36_sentiment_negative_confidence',
#  'mws36_sentiment_phrase_negative',
#  'mws36_sentiment_phrase_positive',
#  'mws36_sentiment_positive_confidence',
#  'mws36_sentiment_words_negative',
#  'mws36_sentiment_words_positive',
#  'mws36_timestamp_time',
#  'mws36_title',
#  'mws36_total_words',
#  'mws38_action',
#  'mws38_entitlement',
#  'mws38_headlinetones_entitlement',
#  'mws38_headlinetones_sg_entitlement',
#  'mws38_headlinetones_sg_time',
#  'mws38_headlinetones_tc_entitlement',
#  'mws38_headlinetones_tc_time',
#  'mws38_headlinetones_time',
#  'mws38_negative_freq',
#  'mws38_negative_score',
#  'mws38_positive_freq',
#  'mws38_positive_score',
#  'mws38_related_num',
#  'mws38_relevances',
#  'mws38_sg_negative_freq',
#  'mws38_sg_negative_score',
#  'mws38_sg_positive_freq',
#  'mws38_sg_positive_score',
#  'mws38_sg_tone_score',
#  'mws38_storyanalytics_entitlement',
#  'mws38_storyanalytics_score',
#  'mws38_storyanalytics_time',
#  'mws38_storyanalytics_type',
#  'mws38_storyanalytics_value',
#  'mws38_tc_negative_freq',
#  'mws38_tc_negative_score',
#  'mws38_tc_positive_freq',
#  'mws38_tc_positive_score',
#  'mws38_tc_tone_score',
#  'mws38_time',
#  'mws38_tone_score',
#  'mws38_uniq_action',
#  'mws38_uniq_entitlement',
#  'mws38_uniq_long_action',
#  'mws38_uniq_long_entitlement',
#  'mws38_uniq_long_related_num',
#  'mws38_uniq_long_relevances',
#  'mws38_uniq_long_time',
#  'mws38_uniq_long_version',
#  'mws38_uniq_new_action',
#  'mws38_uniq_new_entitlement',
#  'mws38_uniq_new_related_num',
#  'mws38_uniq_new_relevances',
#  'mws38_uniq_new_time',
#  'mws38_uniq_new_version',
#  'mws38_uniq_related_num',
#  'mws38_uniq_relevances',
#  'mws38_uniq_time',
#  'mws38_uniq_version',
#  'mws38_version',
#  'mws42_body',
#  'mws42_headline',
#  'mws42_relatednum',
#  'mws42_standalone_headline',
#  'mws42_standalone_relatednum',
#  'mws42_standalone_time',
#  'mws42_standalone_transmission',
#  'mws42_time',
#  'mws42_transmission',
#  'mws46_category',
#  'mws46_elw',
#  'mws46_ens',
#  'mws46_ens_elapsed',
#  'mws46_ens_key',
#  'mws46_ens_key_off',
#  'mws46_ess',
#  'mws46_g_ens',
#  'mws46_g_ens_elapsed',
#  'mws46_mce',
#  'mws46_mcp',
#  'mws46_mcr',
#  'mws46_mcv',
#  'mws46_mean_ens',
#  'mws46_mean_ess',
#  'mws46_mean_nip',
#  'mws46_mean_relevance',
#  'mws46_mean_ssc',
#  'mws46_news_type',
#  'mws46_nip',
#  'mws46_relevance',
#  'mws46_ssc',
#  'mws46_story_count',
#  'mws46_story_index',
#  'mws46_storyid_category',
#  'mws46_storyid_elw',
#  'mws46_storyid_ens',
#  'mws46_storyid_ens_elapsed',
#  'mws46_storyid_ens_key_off',
#  'mws46_storyid_ess',
#  'mws46_storyid_g_ens',
#  'mws46_storyid_g_ens_elapsed',
#  'mws46_storyid_mce',
#  'mws46_storyid_mcp',
#  'mws46_storyid_mcr',
#  'mws46_storyid_mcv',
#  'mws46_storyid_news_type',
#  'mws46_storyid_nip',
#  'mws46_storyid_relevance',
#  'mws46_storyid_ssc',
#  'mws46_storyid_story_count',
#  'mws46_storyid_story_index',
#  'mws46_storyid_time',
#  'mws46_sum_ens',
#  'mws46_sum_ess',
#  'mws46_sum_nip',
#  'mws46_sum_relevance',
#  'mws46_sum_ssc',
#  'mws46_sum_story_count',
#  'mws46_time',
#  'nws48_acb',
#  'nws48_aes',
#  'nws48_bam',
#  'nws48_bee',
#  'nws48_ber',
#  'nws48_ens',
#  'nws48_ens_elapsed',
#  'nws48_ens_similarity_gap',
#  'nws48_ess',
#  'nws48_g_ens',
#  'nws48_g_ens_elapsed',
#  'nws48_g_ens_similarity_gap',
#  'nws48_ghc_lna',
#  'nws48_nip',
#  'nws48_qcm',
#  'nws48_qep',
#  'nws48_qmb',
#  'nws48_relevance',
#  'nws48_rp_story_event_count',
#  'nws48_rp_story_event_index',
#  'nws48_ssc',
#  'nws48_vea',
#  'nws5_01l',
#  'nws5_01p',
#  'nws5_01s',
#  'nws5_02l',
#  'nws5_02p',
#  'nws5_02s',
#  'nws5_10_minutes',
#  'nws5_120_minutes',
#  'nws5_1l',
#  'nws5_1p',
#  'nws5_1s',
#  'nws5_2l',
#  'nws5_2p',
#  'nws5_2s',
#  'nws5_30_minutes',
#  'nws5_30_seconds',
#  'nws5_3l',
#  'nws5_3p',
#  'nws5_3s',
#  'nws5_41rta',
#  'nws5_4l',
#  'nws5_4p',
#  'nws5_4s',
#  'nws5_57l',
#  'nws5_57p',
#  'nws5_57s',
#  'nws5_5_minutes',
#  'nws5_5l',
#  'nws5_5p',
#  'nws5_5s',
#  'nws5_60_minutes',
#  'nws5_90_minutes',
#  'nws5_active',
#  'nws5_allticks',
#  'nws5_allvwap',
#  'nws5_atr_ratio',
#  'nws5_close_vol',
#  'nws5_curr_vol',
#  'nws5_dayopen',
#  'nws5_dividendyield',
#  'nws5_eodclose',
#  'nws5_eodhigh',
#  'nws5_eodlow',
#  'nws5_eodvwap',
#  'nws5_highexcstddev',
#  'nws5_lowexcstddev',
#  'nws5_mainvwap',
#  'nws5_maxdnamt',
#  'nws5_maxdown',
#  'nws5_maxup',
#  'nws5_maxupamt',
#  'nws5_minute',
#  'nws5_mktcap_1000',
#  'nws5_mov_vol',
#  'nws5_open_vol',
#  'nws5_opengap',
#  'nws5_peratio',
#  'nws5_postvwap',
#  'nws5_prev_vol',
#  'nws5_prevclose',
#  'nws5_prevday',
#  'nws5_prevwap',
#  'nws5_range',
#  'nws5_rangeamt',
#  'nws5_rangestddev',
#  'nws5_result',
#  'nws5_result_vs_index',
#  'nws5_shortinterest',
#  'nws5_sl',
#  'nws5_spyclose',
#  'nws5_spylast',
#  'nws5_tonhigh',
#  'nws5_tonlast',
#  'nws5_tonlow',
#  'nws5_vol_ratio',
#  'nws5_volumestddev',
#  'mws50_acb',
#  'mws50_aes',
#  'mws50_bam',
#  'mws50_bee',
#  'mws50_ber',
#  'mws50_category',
#  'mws50_country_code',
#  'mws50_ens',
#  'mws50_ens_elapsed',
#  'mws50_ens_key',
#  'mws50_ens_similarity_gap',
#  'mws50_ess',
#  'mws50_evaluation_method',
#  'mws50_g_ens',
#  'mws50_g_ens_elapsed',
#  'mws50_g_ens_key',
#  'mws50_g_ens_similarity_gap',
#  'mws50_ghc_lna',
#  'mws50_group',
#  'mws50_maturity',
#  'mws50_news_type',
#  'mws50_nip',
#  'mws50_position_name',
#  'mws50_product_key',
#  'mws50_property',
#  'mws50_qcm',
#  'mws50_qep',
#  'mws50_qmb',
#  'mws50_relevance',
#  'mws50_rp_story_event_count',
#  'mws50_rp_story_event_index',
#  'mws50_ssc',
#  'mws50_sub_type',
#  'mws50_time',
#  'mws50_topic',
#  'mws50_type',
#  'mws50_vea',
#  'mws52_chars_in_presentation',
#  'mws52_chars_in_qa',
#  'mws52_conference_call_participants',
#  'mws52_corporate_participants',
#  'mws52_eventtype',
#  'mws52_expirationtime',
#  'mws52_lastuptime',
#  'mws52_occurence',
#  'mws52_occurence_presentation',
#  'mws52_occurence_qa',
#  'mws52_paragraphs_in_presentation',
#  'mws52_position',
#  'mws52_position_presentation',
#  'mws52_position_qa',
#  'mws52_pparagraphs_in_qa',
#  'mws52_questions_in_presentation',
#  'mws52_questions_in_qa',
#  'mws52_sentences_in_presentation',
#  'mws52_sentences_in_qa',
#  'mws52_starttime',
#  'mws52_talks_in_presentation',
#  'mws52_talks_in_qa',
#  'mws52_words_in_presentation',
#  'mws52_words_in_qa',
#  'mws54_eventcallbasicinfo_cancelledflag',
#  'mws54_eventcallbasicinfo_fiscalquarter',
#  'mws54_eventcallbasicinfo_fiscalyear',
#  'mws54_eventcallbasicinfo_postponedflag',
#  'mws54_eventerinfo_calendarmonth',
#  'mws54_eventerinfo_calendaryear',
#  'mws54_eventerinfo_cancelledflag',
#  'mws54_eventerinfo_fiscalquarter',
#  'mws54_eventerinfo_fiscalyear',
#  'mws54_eventerinfo_fullyearflag',
#  'mws54_eventsdaily_headline',
#  'mws54_eventsdaily_situation',
#  'mws54_factor',
#  'mws54_futureeventmkt_headline',
#  'mws54_futureeventmkt_situation',
#  'mws54_keydevelopments_headline',
#  'mws54_keydevelopments_situation',
#  'nws7_area',
#  'nws7_d1_comp_count',
#  'nws7_d1_timestamp',
#  'nws7_display_name',
#  'nws7_headline_negative_freq',
#  'nws7_headline_negative_score',
#  'nws7_headline_tone_score',
#  'nws7_headlinetone_2_news_freq',
#  'nws7_headlinetone_news_freq',
#  'nws7_headlinetones_take_seqno',
#  'nws7_headlinetones_time',
#  'nws7_livenews_freq_qerf',
#  'nws7_livenews_tag',
#  'nws7_news_earning_qerf',
#  'nws7_news_freq_2_qerf',
#  'nws7_news_freq_ins_qerf',
#  'nws7_news_freq_insider_qerf',
#  'nws7_news_freq_lcadata_qerf',
#  'nws7_news_sales_qerf',
#  'nws7_news_tag',
#  'nws7_news_topic_tag',
#  'nws7_newsfreq_d1_qerf',
#  'nws7_related_num',
#  'nws7_sl_d1_comp_count',
#  'nws7_sl_d1_timestamp',
#  'nws7_story_negative_freq',
#  'nws7_story_negative_score',
#  'nws7_story_positive_freq',
#  'nws7_story_positive_score',
#  'nws7_story_time',
#  'nws7_story_tone_score',
#  'nws7_storyheadlinetones_take_seqno',
#  'nws7_storyheadlinetones_time',
#  'nws7_storytone_news_freq',
#  'nws7_tname',
#  'nws7_topic_related_num',
#  'nws7_topic_tname',
#  'nws7_topic_tvalue',
#  'nws7_tvalue',
#  'nws7_usa_livenews_take_seqno',
#  'nws7_usa_livenews_time',
#  'nws7_usa_news_headlinetone_2_negative_freq',
#  'nws7_usa_news_headlinetone_2_negative_score',
#  'nws7_usa_news_headlinetone_2_tone_score',
#  'nws7_usa_news_revisions_d1_time',
#  'nws7_usa_news_storytone_negative_freq',
#  'nws7_usa_news_storytone_negative_score',
#  'nws7_usa_news_storytone_positive_freq',
#  'nws7_usa_news_storytone_positive_score',
#  'nws7_usa_news_storytone_tone_score',
#  'nws7_usa_news_storytones_pzengxth_date',
#  'nws7_usa_news_storytones_pzengxth_negative_freq',
#  'nws7_usa_news_storytones_pzengxth_negative_score',
#  'nws7_usa_news_storytones_pzengxth_positive_freq',
#  'nws7_usa_news_storytones_pzengxth_positive_score',
#  'nws7_usa_news_storytones_pzengxth_take_seqno',
#  'nws7_usa_news_storytones_pzengxth_time',
#  'nws7_usa_news_storytones_pzengxth_tone_score',
#  'nws7_usa_news_time',
#  'nws7_usa_news_topic_time',
#  'nws7_usa_xtangnewsfreqrawnf_daily_raw',
#  'nws77_byte_count',
#  'nws77_commentary_sentiment',
#  'nws77_composite_sentiment_score',
#  'nws77_corporate_actions_sentiment',
#  'nws77_credit_sentiment',
#  'nws77_document_record_count',
#  'nws77_document_record_index',
#  'nws77_document_sentiment',
#  'nws77_document_sentiment_confidence',
#  'nws77_entity_hierarchy_level',
#  'nws77_entity_relevance',
#  'nws77_entity_sentiment',
#  'nws77_entity_sentiment_confidence',
#  'nws77_entity_text_sent_confidence',
#  'nws77_entity_text_sentiment',
#  'nws77_event_detection_distance',
#  'nws77_event_relevance',
#  'nws77_event_risk',
#  'nws77_event_sentiment',
#  'nws77_event_similarity_days',
#  'nws77_interest_rate_sentiment',
#  'nws77_multi_stock_sentiment',
#  'nws77_paragraph_count',
#  'nws77_revision',
#  'nws77_revision_timestamp_utc',
#  'nws77_sentiment_impact_projection',
#  'nws77_source_rank',
#  'nws77_stock_tone_sentiment',
#  'nws77_sustainability_sentiment',
#  'nws77_timestamp_tz',
#  'nws77_timestamp_utc',
#  'nws77_title_similarity_days',
#  'nws77_word_count',
#  'mws87_actinvoratioceopres',
#  'mws87_actinvoratioceoqa',
#  'mws87_actinvoratiocfopres',
#  'mws87_actinvoratiocfoqa',
#  'mws87_analyst_ari_qa',
#  'mws87_analyst_cli_qa',
#  'mws87_analyst_dcs_qa',
#  'mws87_analyst_fkgl_qa',
#  'mws87_analyst_forw_sent_qa',
#  'mws87_analyst_fre_qa',
#  'mws87_analyst_gfi_qa',
#  'mws87_analyst_neg_logit_qa',
#  'mws87_analyst_neu_logit_qa',
#  'mws87_analyst_pos_logit_qa',
#  'mws87_analyst_sent_score_qa',
#  'mws87_analyst_smog_qa',
#  'mws87_analystattendence',
#  'mws87_aq_erf',
#  'mws87_aq_erf_oec',
#  'mws87_aq_erf_ofc',
#  'mws87_aq_ifg',
#  'mws87_aq_ifg_oec',
#  'mws87_aq_ifg_ofc',
#  'mws87_aq_ilc',
#  'mws87_aq_ilc_oec',
#  'mws87_aq_ilc_ofc',
#  'mws87_aq_ira',
#  'mws87_aq_ira_oec',
#  'mws87_aq_ira_ofc',
#  'mws87_aq_lgkf',
#  'mws87_aq_lgkf_oec',
#  'mws87_aq_lgkf_ofc',
#  'mws87_aq_scd',
#  'mws87_aq_scd_oec',
#  'mws87_aq_scd_ofc',
#  'mws87_ari_all',
#  'mws87_ceo_forw_sent_pres',
#  ...]

# %% [markdown]
# #### Step 3. Create expression list, using selected datafields
# Here is an example: creating expressions that assign weights as per the time series skewness of vector average of the field value

# %%
# Thay Operators 
expression_list = [f'-vec_avg({x})' for x in all_data_field] # create a list of alpha expressions ts_skewness(vec_avg({x}),120) where x is a datafield id

# %%
alpha_list = []
for universe in ['TOP200','TOP3000','TOP500','TOP1000']:
    for decay_Value in range(1,10,1):
        for trun_value in [i/10 for i in range(0, 11)]:
            for neutralization_Value in ['MARKET','INDUSTRY','NONE','SUBINDUSTRY','SECTOR']:
                alpha_list.append([ace.generate_alpha(x, region= "USA", universe = universe, decay = decay_Value, neutralization = neutralization_Value, truncation= trun_value) for x in expression_list])

alpha_list = [item[0] for item in alpha_list]

# %%
import random

random_list = [random.randint(1, 1000) for _ in range(400)]

# %%
alpha_list = [alpha_list[i] for i in random_list]

# %% [markdown]
# #### Step 4. Apply generate_alpha function to the expression list
# In generate alpha function you can specify region, universe, decay, delay and other simulation settings

# %%
#alpha expressions are sliced to first 10 for demonstration purpose
# Chạy nhiều hơn thì thay 10 thành số khác
result = ace.simulate_alpha_list_multi(s, alpha_list)

# %%
len(alpha_list)
# Out:
# 400
# An error occurred
# An error occurred

# %%
# #when you send multiple alphas for simulation, please make sure all alphas of a single list should have common settings
# #alphas with different settings should be sent in a different list, for instance below list has all alphas with same settings

# alpha_list = [ace.generate_alpha(x, region= "USA", universe = "TOP3000",delay = 1, decay= 0, neutralization  = "INDUSTRY", truncation = 0.08, pasteurization = "ON",test_period = "P0Y0M0D",unit_handling = "VERIFY", nan_handling= "OFF") for x in expression_list]

# alpha_list[0]

# %% [markdown]
# This is an example - how alpha actually looks like when you send it to the platform.

# %% [markdown]
# ### Simulate alpha list, get simulation result
#
# simulate_alpha_list_multi will do a multi-simulation if list of alphas is greater than 10, which is the case here
#
# the returned object will contain simulation results for all alphas as a list

# %%
#alpha expressions are sliced to first 10 for demonstration purpose
# Chạy nhiều hơn thì thay 10 thành số khác
result = ace.simulate_alpha_list_multi(s, alpha_list)
# Out:
# 100%|██████████| 330/330 [1:41:27<00:00, 18.45s/it]

# %% [markdown]
# __Accessing the result of the first alpha, let's take a look at all the keys of this dictionary__

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#           pnl  book_size  long_count  short_count  turnover  returns  \
# 0    27427876   20000000         500            0    0.1536   0.2746
# 1    27227642   20000000         500            0    0.1547   0.2726
# 2    27284092   20000000         500            0    0.1545   0.2732
# 3    27208232   20000000         500            0    0.1548   0.2724
# 4    27208232   20000000         500            0    0.1548   0.2724
# ..        ...        ...         ...          ...       ...      ...
# 985 -11494767   20000000         158          341    0.4545  -0.1151
# 986 -11480770   20000000         158          341    0.4544  -0.1149
# 987 -11492412   20000000         158          341    0.4545  -0.1151
# 988 -11183561   20000000         158          341    0.4520  -0.1120
# 989 -10366360   20000000         159          340    0.4488  -0.1038
#
#      drawdown    margin  fitness  sharpe  ...                      expression  \
# 0      0.5232  0.003576     1.14    0.85  ...  vec_avg(scl12_alltype_buzzvec)
# 1      0.5232  0.003524     1.12    0.84  ...  vec_avg(scl12_alltype_buzzvec)
# 2      0.5232  0.003536     1.12    0.84  ...  vec_avg(scl12_alltype_buzzvec)
# 3      0.5232  0.003520     1.11    0.84  ...  vec_avg(scl12_alltype_buzzvec)
# 4      0.5232  0.003520     1.11    0.84  ...  vec_avg(scl12_alltype_buzzvec)
# ..        ...       ...      ...     ...  ...                             ...
# 985    1.1759 -0.000506    -0.46   -0.92  ...  vec_avg(scl12_alltype_buzzvec)
# 986    1.1745 -0.000506    -0.46   -0.92  ...  vec_avg(scl12_alltype_buzzvec)
# 987    1.1756 -0.000506    -0.46   -0.92  ...  vec_avg(scl12_alltype_buzzvec)
# 988    1.1447 -0.000495    -0.47   -0.94  ...  vec_avg(scl12_alltype_buzzvec)
# 989    1.0608 -0.000462    -0.48   -0.99  ...  vec_avg(scl12_alltype_buzzvec)
#
#     concentrated_weight high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0                  FAIL          PASS             FAIL        PASS       FAIL
# 1                  FAIL          PASS             FAIL        PASS       FAIL
# 2                  FAIL          PASS             FAIL        PASS       FAIL
# 3                  FAIL          PASS             FAIL        PASS       FAIL
# 4                  FAIL          PASS             FAIL        PASS       FAIL
# ..                  ...           ...              ...         ...        ...
# 985                FAIL          PASS             FAIL        FAIL       FAIL
# 986                FAIL          PASS             FAIL        FAIL       FAIL
# 987                FAIL          PASS             FAIL        FAIL       FAIL
# 988                FAIL          PASS             FAIL        FAIL       FAIL
# 989                FAIL          PASS             FAIL        FAIL       FAIL
#
#     low_sub_universe_sharpe low_turnover matches_competition matches_themes
# 0                      FAIL         PASS             WARNING           PASS
# 1                      FAIL         PASS             WARNING           PASS
# 2                      FAIL         PASS             WARNING           PASS
# 3                      FAIL         PASS             WARNING           PASS
# 4                      FAIL         PASS             WARNING           PASS
# ..                      ...          ...                 ...            ...
# 985                    FAIL         PASS             WARNING           PASS
# 986                    FAIL         PASS             WARNING           PASS
# 987                    FAIL         PASS             WARNING           PASS
# 988                    FAIL         PASS             WARNING           PASS
# 989                    FAIL         PASS             WARNING           PASS
#
# [990 rows x 22 columns]

# %%
result_st1['is_ladder_sharpe'].value_counts()
# Out:
# FAIL    990
# Name: is_ladder_sharpe, dtype: int64

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df.head()
# Out:
#   alpha_id        date endDate  limit matched                 name result  \
# 0  GoEK9KZ         NaN     NaN   1.58     NaN           LOW_SHARPE   FAIL
# 1  GoEK9KZ         NaN     NaN   1.00     NaN          LOW_FITNESS   FAIL
# 2  GoEK9KZ         NaN     NaN   0.01     NaN         LOW_TURNOVER   PASS
# 3  GoEK9KZ         NaN     NaN   0.70     NaN        HIGH_TURNOVER   FAIL
# 4  GoEK9KZ  2019-07-10     NaN   0.10     NaN  CONCENTRATED_WEIGHT   FAIL
#
#   startDate themes unmatched     value  year
# 0       NaN    NaN       NaN -0.740000   NaN
# 1       NaN    NaN       NaN -0.200000   NaN
# 2       NaN    NaN       NaN  1.207300   NaN
# 3       NaN    NaN       NaN  1.207300   NaN
# 4       NaN    NaN       NaN  0.452952   NaN

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['GoEK9KZ' 'V8Kmez5' 'V8Kme55' 'oYQJZGl' 'jgNPOxW' 'jgNPOOW' 'WgKoJrG'
#  'QQmN6xG' 'O9KMg3p' 'V8KmRZM' 'mXe0l0x' 'JdRW2zl' 'WgKoRjG' 'P1jYbQp'
#  'Rr0loMd' 'l0J5Ybx' 'ereVPRp' 'QQmNAdM' 'O9KMjM1' 'QQmNAzM' 'EKo8MLJ'
#  'p7QMeXg' 'QQmNpJW' 'nWwe5R8' 'KLx5AXg' 'xnX27el' 'qXeY2gA' 'Mx9evYL'
#  '5vNAKJM' 'rWQNa0o' 'Zokd8d8' 'O9KMLzg' 'GoEK2xQ' 'dQe3M3Y' 'vmapEGA'
#  'kKeWwOg' 'Rr0lO91' 'YAXEVEw' 'ereVYGJ' 'vmapQZb' 'XKXv0v8' 'A3qrAzW'
#  'qXeYRaV' '8LgEww7' '3AgkN8e' '2KPX3w8' 'l0J5oKO' 'YAXERx6' '7dgmkn8'
#  'aOXzrE5' 'weXG8jx' 'JdRzV2x' 'V8KzvLY' 'xnXGKpg' '1g6KYKQ' 'dQez5o2'
#  'Rr0zRPj' 'qXeG9kv' 'weXGKOx' 'V8Kz1qA' 'l0JGpNe' '8LgJ5Zm' 'A3qzj5Q'
#  'A3qz9Rd' 'YAXz6P6' '3AgPwqP' 'YAXz6lM' '1g6KeOz' 'LROzWmn' 'QQmzMpM'
#  'dQezpJw' 'zWXGZxK' '5vN5bbJ' 'g37GAOQ' 'dQezXAg' '9RgMv3r' 'rWQG3Mj'
#  'EKoz7nR' 'KLxz0A1' 'P1jzWVJ' 'xnXG6ZJ' '9RgM1Ro' 'GoEzAwP' '08ng376'
#  'KLxzdoj' 'LROzaQa' 'Rr0zQGn' 'jgNGbE9' 'P1jzdaq' '1g6KQQk' 'XKXz5RX'
#  'YAXzG1q' 'oYQGMEk' 'g37GEgM' 'Rr0znz1' 'vmaG36d' '9RgM0Lo' 'p7QGOOq'
#  'JdRzKK2' 'vmaGgOG' 'JdRzKex' 'rWQGX7E' 'xnXGaAq' 'qXeGZMV' 'GoEzv1Q'
#  '3AgPWQg' 'LROzxWL' '5vN5VxJ' 'Rr0zLEa' 'vmaGVAa' 'kKeG58l' '8LgJqMq'
#  'EKozA9P' 'p7QG0q3' '1g6KvJz' 'dQezqQE' 'qXeGbAZ' 'nWwqwKx' 'kKeGeVz'
#  '1g6K6XK' 'aOXz2JO' '8LgJkgq' '9RgMPPq' 'g37Gq9Q' 'dQez8Zj' 'zWXGwkO'
#  '9RgMPWe' 'weXGw92' 'NOkzWNe' 'weXGOJ1' '5vN53a6' '3AgP3EZ' 'l0JGkKN'
#  'NOkzqe8' 'rWQGER9' '8LgJ7Xv' '1g6K12z' 'dQezg6E' 'EKozbpK' 'zWXGjbo'
#  'oYQGvon' 'aOXzPYR' 'JdRzXEe' '5vN56oz' 'jgNGw89' 'g37GPWv' 'QQmzlvM'
#  'P1jzlmM' 'kKeGmp6' 'O9KzmLJ' 'nWwqOn3' 'g37GoxK' 'rWQGrWm' 'xnXGmGJ'
#  'vmaGJ6b' '08ngK5r' 'O9Kz5lY' 'A3qzOoX' 'A3qzgRX' 'A3qzgPQ' 'qXeGP6j'
#  '2KP6apN' 'g37GmKO' '1g6KoLM' 'XKXzkla' 'b97zNvZ' 'KLxznk1' 'xnXGenl'
#  'jgNGn6k' '08ngAwr' 'dQeznOx' 'dQezdxX' 'jgNG1ZO' '2KP6JLx' '1g6KJz6'
#  '7dgmJzO' '2KP6Jlb' '9RgMRR1' 'nWwqWWE' 'P1jz1pM' '08ng8Rk' 'Zokzobx'
#  'NOkzOae' 'l0JGV32' 'P1jzpGw' 'ereGOzO' '5vN5w55' 'KLxzbQg' 'vmaGLPr'
#  'xnXGxol' '2KP67o5' 'weXGR7Y' 'O9KzZxq' 'oYQGlN5' 'vmaGlj3' 'dQezR2J'
#  'A3qz71E' 'p7QGKYj' '2KP6NZ8' 'NOkzR5w' '3AgPenP' 'WgKzV0N' 'QQmz96X'
#  'xnXGdEq' 'xnXGNXw' '9RgMpPK' 'GoEzGYJ' '08ngpKv' '9RgMpA2' 'GoEzGMQ'
#  'xnXGNoN' 'XKXzoAl' '5vN5pKo' 'Rr0z7Ld' 'zWXGkaX' '7dgmjgO' 'weXGjl5'
#  'dQezj0Y' '9RgMX71' '9RgMX2d' 'jgNGjJe' 'Mx9z7Nk' 'QQmz3dW' '1g6KxvW'
#  'b97zR7R' '8LgJ36v' '9RgMVAr' 'vmaGkez' '8LgJ3Wv' 'XKXzWZ0' 'oYQG6b6'
#  'g37GbRO' 'ZokzbjY' 'QQmzbnw' 'qXeGxEK' 'aOXzbV5' '08ngXY2' 'JdRzNAm'
#  'QQmzbxw' '1g6KXMM' 'jgNG8lQ' 'l0JGKke' '1g6KZ1R' 'Mx9z3QM' 'LROzZ12'
#  'LROzZd2' 'aOXzxVv' 'ereGQ5p' 'ereGQap' 'Rr0zALd' 'zWXGraX' 'ereG6ep'
#  '7dgmoY5' 'V8KzdMY' 'qXeGE52' 'dQezKNY' '2KP6A1N' 'NOkzN1q' 'p7QGd06'
#  'l0JGAJ7' 'dQezW8X' 'oYQGEjv' 'KLxzJA1' 'LROzMvM' '9RgMlP9' 'dQezagg'
#  'weXGo16' '08ngPd1' '1g6KWmM' 'Rr0zeko' 'zWXGAMR' 'O9Kz6P1' 'kKeG8rP'
#  'rWQG0l1' '1g6KGdM' 'oYQGPgJ' 'Rr0z57n' 'jgNGVjO' '5vN5GQ5' 'oYQGPZE'
#  'qXeG5wj' 'GoEzQNo' 'KLxzvGN' 'dQezYjg' 'Mx9zd1M' 'WgKz3lG' 'dQezY9X'
#  'g37GXre' 'qXeGOYZ' 'Mx9zdzo' 'NOkzL3o' 'YAXzEzW' '9RgMdmo' 'dQez3vX'
#  '5vN5AKn' '5vN5Amn' 'rWQGNx3' 'Rr0zlxe' 'A3qzrpl' 'NOkzJZp' 'KLxzzLg'
#  'Rr0zzpe' 'EKozzER' '5vN5exn' 'EKozL1P' 'dQezoXJ' 'P1jz8rW' '9RgMmP2'
#  'xnXGW9W' 'O9KzVoJ' 'zWXG0WO' 'JdRz1pm' '3AgPJZX' 'dQezvLK' 'EKozxAR'
#  'qXeGV5Z' 'b97zAJZ' 'P1jzKYJ' 'jgNGOxe' 'kKeG99P' 'rWQG8nJ' 'Rr0zvno'
#  'b97zKER' 'b97zK3R' 'dQezP9v' 'mXe7ldK' 'GoEz7KG' 'Rr0zvPn' 'aOXzggv'
#  'nWwqXlx' 'oYQGkkv' 'xnXGEon' 'kKeGY6k' 'b97zgJr' 'g37G5gQ' 'dQez6zg'
#  'XKXzx00' 'JdRzk62' 'O9KzX1R' 'xnXGpaN' '7dgmROQ' '7dgmRgZ' 'XKXzAaz'
#  'YAXzoll' 'P1jzmxK' 'jgNGkbE' 'V8KzQgb' 'rWQGaX8' 'XKXzZX8' 'YAXz3wl'
#  '6Eg063p' 'l0JGnb7' 'XKXz361' '9RgMeQo' 'XKXz3Y8' 'WgKzZad' 'O9KzLnq'
#  'V8Kzr7w' 'LROzv9L' 'A3qzp0X' 'aOXzpOO' 'weXGrR1' 'O9Kz3Z1' 'EKozdRm'
#  'oYQGdoE' 'aOXzpK1' 'XKXz09l' '6Eg0kMY' 'QQmz8WX' 'QQmzw9G' 'LROz0Gn'
#  'A3qzolY' 'V8KzAMM' 'Rr0zG91' 'mXe7E0x' 'KLxzWAp' 'KLxzWop' 'vmaGWQG'
#  'O9KV1Vq' 'EKoLZxJ' 'GoExq95' 'EKoLZ99' 'aOXwkk6' 'XKXeggx' 'YAXJPGW'
#  'ZokMYGx' '8LgY8qa' 'EKoL5nP' 'nWwQpjl' 'erev7j6' 'rWQVpgm' 'A3qmjMd'
#  'A3qmjKd' 'vma6wga' 'EKoLOA0' 'weXPK66' '1g6Peem' 'ZokM65j' 'Rr0KMQ0'
#  'kKeOdld' 'QQmgMXp' 'xnXWqaW' 'P1j8N3x' 'ZokM6K0' 'QQmgMGg' 'jgNxEjj'
#  '3Ag5b96' 'xnXW63g' 'l0J9qEl' 'erevpVd' '8LgYoJz' '7dgMb95' 'JdR1EL2'
#  'ZokM3Z0' 'O9KVPWd' 'WgK0QYG' 'Rr0KQ9n' 'QQmgkog' '9Rgm1Oq' '9Rgm15q'
#  'P1j8ddM' 'dQeoALj' 'zWX01zO' 'dQeoLkw' 'GoExJ15' 'p7QZOm3' 'EKoLJJm'
#  'XKXe6El' 'g37dpvK' 'EKoLJqL' 'NOk39Ae' 'erevRrz' '1g6P5dM' '2KPWkNw'
#  'NOk3obg' 'mXe1kVK' 'YAXJdvW' 'QQmgdGw' 'nWwQbN8' 'xnXWajg' '8LgYqla'
#  '8LgYApl' 'rWQVkjo' 'dQeoqOg' 'oYQr2am' 'aOXwJa9' 'GoExVQx' '8LgYAEv'
#  'oYQr2Gv' '3Ag5dPO' 'xnXWX9g' 'zWX0XQV' 'p7QZQzq' 'LROrO9m' 'GoExEbo'
#  'QQmgmKX' 'dQeoerE' 'jgNxNkE' 'WgK0KZj' 'mXe12zX' 'erev8qg' 'KLxQYXj'
#  'EKoL06K' 'jgNxlaQ' 'V8K5wNA' 'vma6n7G' 'zWX0wxd' '08n6kJp' 'ZokMqnY'
#  'LROrq12' 'EKoLYG1' 'EKoLYvr' 'zWX0Q8X' 'nWwQYPx' 'erevKRE' '9RgmKQd'
#  'LROr6eM' 'p7QZEPg' 'QQmgj3W' 'l0J92vO' 'dQeomJx' 'vma69Ed' 'A3qmbAg'
#  'oYQrz1b' 'qXe3zMV' 'zWX0oKE' '1g6PmdX' 'dQeo7Rx' 'A3qmaGg' 'rWQVzZ3'
#  'QQmg51M' 'jgNxd5k' 'Rr0KkWj' '9RgmAQ1' 'oYQr9eb' 'oYQr93m' 'aOXwWA9'
#  'erevqnz' 'l0J9QOl' 'vma6eMb' '8LgYadz' 'dQeoEpJ' 'GoExMaO' '3Ag5arZ'
#  'zWX0PpK' 'P1j8w97' 'dQeoEww' 'b97noAq' 'p7QZVpV' 'O9KVbjY' '5vNeadM'
#  '9Rgma51' 'weXPn7d' 'jgNx9MZ' 'KLxQXp8' 'A3qmg5X' 'LROrnN2' 'A3qmnve'
#  'JdR1nPx' '3Ag5ElP' 'dQeonOv' 'Rr0KNbo' 'mXe1q6K' 'Mx9Zb0a' 'JdR1nex'
#  'GoExkOZ' 'V8K5OdG' 'aOXwoK6' 'oYQrVE2' 'ZokMrQd' 'oYQrVal' '2KPWK8P'
#  'kKeOKdd' '9RgmRY2' '8LgYLRm' '9RgmRx2' 'aOXwOa1' '9RgmRd9' 'qXe3XG1'
#  'Mx9Zxzz' '8LgYzbq' '1g6P79k' '1g6P7bk' 'GoExw3Z' '1g6P7aW' 'A3qmwnw'
#  'nWwQgg8' '5vNewOk' '9Rgmw7o' 'LROrpv6' 'l0J9VmO' 'P1j8pVL' 'JdR1OOW'
#  'LROr1d9' 'EKoLEGG' 'xnXWkbg' 'Rr0K8An' 'xnXWkrg' 'g37dMdv' '1g6Pd0k'
#  'jgNx0Ok' 'oYQrg6b' '6EgJejK' 'rWQVPeo' 'P1j8GJK' '6EgJpXJ' 'Rr0Kmjz'
#  'LROrGE6' 'A3qmGrd' 'p7QZNMb' '2KPWpWZ' 'kKeOP9l' 'xnXWN5p' 'jgNxjRk'
#  'P1j87dK' '6EgJlOJ' 'xnXWjGW' '2KPWlWN' 'WgK07JN' 'KLxQ7MN' '2KPWlV8'
#  'vma6j7v' '6EgJra7' 'oYQr63b' 'b97nRNr' 'oYQr6Wm' 'GoExdOx' 'WgK0PLo'
#  'JdR1Nl2' '5vNezN5' 'xnXW3wn' 'EKoLpxr' 'GoExb73' '5vNez1n' 'WgK0e9j'
#  '9RgmWJd' '7dgM6d1' 'jgNx8JO' 'XKXeJAa' '1g6PZ3z' 'vma627z' 'A3qmvpY'
#  '2KPWmYb' 'ZokMmA3' 'LROr5Zv' 'YAXJxxl' 'nWwQAjw' 'erev6jg' 'KLxQmWj'
#  '1g6PjrM' '2KPWA1x' 'kKeONq8' 'oYQra2v' 'b97na7Z' 'ZokMak1' 'YAXJamA'
#  'P1j85lq' 'A3qmxOW' '08n6G7K' 'LROr81e' 'O9KV6xq' '9RgmGW2' 'JdR13PO'
#  'P1j8Pow' 'g37dXxm' 'EKoLNK1' 'A3qmewR' 'mXe1dg1' 'kKeOvoP' 'P1j8xg7'
#  'QQmgORW' 'GoExX2G' 'weXP3rl' 'Rr0Kl2j' 'O9KVMnY' 'YAXJENJ' 'xnXWGOb'
#  '2KPW6Mw' 'weXPGml' 'V8K5zqJ' 'LROrzqv' '2KPW6R5' 'qXe3GmK' 'qXe3GPK'
#  'YAXJz2R' 'dQeooXg' 'qXe33r1' '2KPWWb8' 'O9KVVwv' 'zWX00wV' 'jgNxxWO'
#  'vma665b' '7dgMMJv' 'jgNxxge' '6EgJJGL' '8LgYYVX' 'QQmggNW' 'zWX0ezE'
#  '2KPWeE6' 'erevEeN' 'vma6P5w' 'aOXwGN9' 'p7QZ38x' '1g6P0AW' 'XKXeMZ1'
#  '6EgJNWO' 'oYQrZxm' 'zWX0elV' 'JdR12V2' 'NOk32j7' 'erevWqO' 'xnXWEPm'
#  'dQeoPYw' 'Rr0Kvl0' 'mXe1l7p' 'P1j8bQE' 'P1j8bNE' '1g6PR96' 'P1j8bZL'
#  'O9KVjNJ' 'Mx9Zn38' 'l0J9YEn' '1g6PRlK' 'oYQrXG6' 'KLxQMjp' 'O9KVXaJ'
#  '7dgMRVL' 'weXPkbQ' 'QQmgpYQ' 'O9KVXAb' 'aOXw9a6' '08n62P1' '5vNedGX'
#  'qXe32qV' 'erevMJO' 'O9KVdeY' '3Ag5mV0' 'O9KVdJ7' 'qXe32Lv' 'EKoLnRK'
#  'qXe32Ev' 'XKXeZ9m' 'JdR1a9x' '1g6P3rz' 'O9KVL1p' 'WgK0Zld' 'oYQrbak'
#  'KLxQoVE' '1g6P8RQ' 'dQeoMr2' 'zWX0xnE' 'P1j8VEJ' 'rWQVxm8' 'LROrQeM'
#  '5vNeXY6' 'LROrQ3v' '9Rgmn2K' 'LROr0J2' 'zWX0lzd' '8LgYMAa' 'JdR16be'
#  '8LgYMLz' 'vma6WLd' 'JdR16An' '7dgMe5v' 'V8K5AWJ' 'EKoxZbL' 'zWXevod'
#  'WgKJEWG' 'xnX5KVq' 'LRO3PmL' 'aOXGrz6' 'vmaPR0A' 'b97Al7q' 'aOXGkMw'
#  'aOXGk8w' 'NOk81l8' 'YAXYP3J' 'ZokNYJd' 'zWXeqlO' 'YAXYLjW' 'V8Ke1nJ'
#  'LRO3Vev' 'dQevkeJ' '6EgNm2p' 'O9KgQj7' 'qXeV9Jv' '1g60e6z' 'O9KgOwp'
#  'vmaP8xz' '7dglWLx' 'oYQZ7al' 'JdRrq3m' 'rWQ8YxJ' 'LRO3W0e' 'Rr0P3J0'
#  'EKox7xL' 'A3qEW2e' '7dglArL' '8LgXoMW' 'dQevV2K' 'oYQZ5m6' 'ZokN3Qj'
#  'xnX58vw' 'dQevV9w' 'dQevVGv' 'GoE9AZG' 'JdRrZVm' '9RgkL91' 'O9KgEoY'
#  'LRO3ARL' 'YAXYG1o' 'O9KgEWp' '08n50Gq' 'YAXYG3w' '08n50Vv' '1g60QMQ'
#  'YAXYqNl' 'dQevLdx' 'A3qEK3g' 'p7Q3Oa6' 'kKe9l8K' '5vNYWrk' '7dglVOx'
#  'l0J1ZJO' 'QQm6dmw' 'ereEJLp' '6EgNbz5' '9RgkQwq' 'dQevqgg' 'vmaP09a'
#  'LRO3eX6' 'g37Lvo0' 'mXeQOrX' 'ereEAng' 'vmaP0Nr' 'jgNOLj9' 'nWwr0Kz'
#  'EKoxok0' 'b97A79l' 'XKXMXKx' 'l0J1JW7' 'KLxZx7j' 'oYQZQ6m' 'LRO3O31'
#  'qXeVewv' 'weXWXAx' 'xnX5wmw' 'Rr0PZ20' 'xnX5wew' 'Rr0PZ7a' 'dQev8Og'
#  '7dglqNb' 'V8Kewr8' 'Rr0PZg0' 'Mx9Vlrr' '5vNY3zo' 'g37LwZJ' 'Rr0Pq6z'
#  'aOXGM89' 'KLxZqMg' 'V8KeqQ0' 'rWQ8Eq8' 'xnX59Zl' '9RgkKqq' 'qXeVdWO'
#  'b97AMb6' '8LgXrPz' 'vmaP96Q' 'p7Q3E3b' 'XKXMLOx' 'A3qEa1R' 'ereE27E'
#  'KLxZ8lg' '9Rgk6pe' '08n5Qwp' 'zWXeokV' 'QQm6lN5' '9Rgk6MK' 'mXeQz1p'
#  'P1jKlbW' 'Rr0Paoz' '7dglXRZ' 'weXWJEQ' 'rWQ8r2o' 'EKoxrl0' 'oYQZ9Zk'
#  'XKXMYO8' 'weXWJAY' '1g60aQW' '9Rgka0x' 'dQevEwj' 'A3qEg0Q' 'qXeVPxj'
#  'YAXY2Mv' '2KPev8Y' 'dQevnpx' 'V8KeX9M' 'b97ANkp' 'NOk8nmX' 'QQm6nkp'
#  '9Rgk9Ae' 'LRO3ng2' 'kKe9nn8' 'A3qEkkw' 'mXeQZXX' 'aOXGodW' 'Rr0Pdda'
#  'kKe9QKl' 'ereELOl' '7dglJNO' 'l0J1rvn' 'LRO3kZM' 'XKXMKlz' 'A3qE3Og'
#  'KLxZLwz' '2KPeKwZ' 'QQm6Qbw' '08n58rk' 'Rr0Ppnb' 'Rr0PpWb' 'l0J1VZ7'
#  'zWXemKK' 'ereE0kM' 'V8KePVM' 'P1jK3dW' 'dQev0L2' 'mXeQb9W' 'vmaPvRz'
#  '5vNYknn' 'V8Ke31b' 'Rr0P1qz' 'NOk8R67' '08n5MQ8' '1g60zGm' 'dQevRYw'
#  'EKoxe8J' 'JdRrGE2' '6EgNpvG' '1g60pEz' 'oYQZNYb' '2KPep76' 'V8KeGPG'
#  'P1jKGYJ' 'ZokNEd1' 'dQevZzK' 'LRO37V6' 'zWXekZ1' 'jgNOjE5' 'b97Ajjq'
#  'LRO379L' 'p7Q3jPv' 'kKe9jg6' 'LRO3756' 'p7Q3jvb' 'jgNOjpe' 'weXWjrY'
#  '6EgNl5p' 'ZokN0Md' 'rWQ8589' 'EKoxv2G' 'LRO39z6' 'xnX5YWm' 'YAXY5Y6'
#  'QQm6bJM' '9Rgkj1q' '7dglNE8' 'A3qEN8d' 'l0J1vPN' 'Rr0Pbxa' 'mXeQ6k5'
#  'LRO3Zxv' 'P1jKgeq' 'KLxZrV1' '8LgXPVW' 'dQev13J' '1g60j56' 'mXeQYkE'
#  'qXeVEb2' '6EgNAJG' '9RgkEkr' 'mXeQYl2' 'A3qEQ8E' '7dgloPv' 'YAXYxVA'
#  'V8Kexn5' 'Rr0PE0b' 'p7Q3dJg' '9Rgkx5o' 'xnX5rLg' 'XKXM930' 'NOk8K0E'
#  'Mx9VgWn' 'KLxZVd1' 'p7Q3WAo' '8LgXGdW' 'A3qELKE' 'KLxZvKN' 'oYQZRm2'
#  '08n5xmG' 'xnX5VKm' 'XKXMVjx' '3AgJ1qe' 'ZokNg6d' 'O9KgRYJ' 'JdRroEm'
#  'A3qEeEY' 'JdRro2E' '08n5xLq' 'O9KgRzv' 'weXW3Pp' 'NOk8L3E' 'QQm6NdQ'
#  'jgNOPLW' 'weXW2X6' 'dQev3bY' 'xnX52bW' 'EKox8Vm' 'YAXYExw' 'rWQ8NRm'
#  '3AgJk0g' 'kKe9Wzk' 'P1jKzJJ' 'EKoxzZP' 'nWwrqKz' 'rWQ8GO3' 'vmaPGrb'
#  'JdRrz7E' 'V8Kez7b' 'xnX5GYl']
# Passed alphas:[]
